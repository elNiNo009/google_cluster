# %%
import pandas as pd

# %%
job_1 = pd.read_csv('/home/sarthak/Desktop/part-00000-of-00500.csv')

# %%
job_1
# Out:
#              time  missing      job_id  event type  \
# 0               0      NaN     3418309           0
# 1               0      NaN     3418314           0
# 2               0      NaN     3418319           0
# 3               0      NaN     3418324           0
# 4               0      NaN     3418329           0
# 5               0      NaN     3418334           0
# 6               0      NaN     3418339           0
# 7               0      NaN     3418356           0
# 8               0      NaN     3418363           0
# 9               0      NaN     3418368           0
# 10              0      NaN     3418375           0
# 11              0      NaN     3418380           0
# 12              0      NaN     3418385           0
# 13              0      NaN     3418390           0
# 14              0      NaN     3418395           0
# 15              0      NaN     3418400           0
# 16              0      NaN     3418405           0
# ...

# %%
job_1.drop(['missing', 'user', 'job_NAME' , 'logica_JOB_NAME'], axis=1)
# Out:
#              time      job_id  event type  SC
# 0               0     3418309           0   3
# 1               0     3418314           0   3
# 2               0     3418319           0   3
# 3               0     3418324           0   3
# 4               0     3418329           0   3
# 5               0     3418334           0   3
# 6               0     3418339           0   3
# 7               0     3418356           0   3
# 8               0     3418363           0   3
# 9               0     3418368           0   3
# 10              0     3418375           0   3
# 11              0     3418380           0   3
# 12              0     3418385           0   3
# 13              0     3418390           0   3
# 14              0     3418395           0   3
# 15              0     3418400           0   3
# 16              0     3418405           0   3
# 17              0     3418412           0   3
# 18              0     3418417           0   3
# ...

# %%
count=job_1.groupby(["SC"]).size().reset_index(name="freq")

# %%
count
# Out:
#    SC  freq
# 0   0  2179
# 1   1  3610
# 2   2  3030
# 3   3  1885

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
% matplotlib inline

# %%
ypos=np.arange(len(count['SC']))

# %%
ypos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(ypos,count['freq'],label="profit")
# Out:
# <BarContainer object of 4 artists>
